# %%
import plotly.express as px
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %%
country_codes = pd.read_csv('../countries_codes_and_coordinates.csv' , sep = ',', index_col = 0)

# %%
data = pd.read_csv('results/optimization_results_CHU_world_grid.csv')
data = data.set_index('Country')
# data = data.drop(['Antarctica'], axis =0)
for col in data.columns[2:]: 
    data[f'{col}_normalized']=data[col]/data['mean_load']
    
for c in data.index.to_list(): 
    results = pd.read_pickle(f'results/{c}/Chu/optimization_results_None.pickle')
    iso_code = country_codes.loc[c,'Alpha-3 code' ].split(' ')[1]
    data.loc[c, 'capacity_factor_wind'] = results['E_wind']/data.loc[c, 'P_wind']/8760
    data.loc[c, 'capacity_factor_pv'] = results['E_pv']/data.loc[c, 'P_pv']/8760
    data.loc[c, 'capacity_factor_dispatch'] = results['E_dispatch']/data.loc[c, 'P_dispatch']/8760
    data.loc[c, 'share_dispatchable'] = results['E_dispatch']/(results['E_wind']+results['E_pv']+results['E_dispatch'])*100
    data.loc[c, 'share_wind']=results['E_wind']/(results['E_wind']+results['E_pv']+results['E_dispatch'])*100
    data.loc[c, 'share_pv']=results['E_pv']/(results['E_wind']+results['E_pv']+results['E_dispatch'])*100
    # data.loc[c, 'carbon_impact']=results['E_wind']*11+results['E_pv']*45/pop/1000

# %%
data
# Out:
#              State iso_alpha     mean_load    E_dispatch    P_dispatch  \
# Country
# France         NaN       FRA  57578.762785  3.632089e+08  86210.790986
# Afghanistan    NaN       AFG    810.466324  4.560043e+06    918.956912
# Albania        NaN       ALB    833.338813  8.358831e+06   1148.740405
# Algeria        NaN       DZA   7850.452511  7.125742e+07  10346.271876
# Angola         NaN       AGO   1114.159589  1.034886e+07   1364.388081
# ...            ...       ...           ...           ...           ...
# Venezuela      NaN       VEN  13311.642237  8.905333e+07  17217.323501
# Vietnam        NaN       VNM  17678.079909  1.006357e+08  21040.013010
# Yemen          NaN       YEM    607.305822  3.536228e+06    835.436892
# Zambia         NaN       ZMB   1488.580594  1.111569e+07   2184.047999
# Zimbabwe       NaN       ZWE   1097.036530  5.600002e+06   1671.347227
#
#                 E_destock           P_pv         P_wind  mean_load_normalized  \
# Country
# France       4.006273e+08  156206.003051  137963.574004                   1.0
# Afghanistan  5.658201e+06       0.744987    3140.040842                   1.0
# Albania      1.471465e+07       2.705604    1670.367638                   1.0
# Algeria      6.214469e+07       8.704634   23132.786918                   1.0
# Angola       1.777510e+07       3.111432    5179.315297                   1.0
# ...                   ...            ...            ...                   ...
# Venezuela    1.974158e+08   62969.470864   11344.880363                   1.0
# Vietnam      2.311443e+08   84540.394158   32641.386180                   1.0
# Yemen        4.997981e+06    1262.936824    1387.888771                   1.0
# Zambia       2.083223e+07    6449.170419    1185.884144                   1.0
# Zimbabwe     1.606583e+07    4322.358918    1430.473821                   1.0
#
#              E_dispatch_normalized  P_dispatch_normalized  \
# Country
# France                 6308.034995               1.497267
# Afghanistan            5626.443283               1.133862
# Albania               10030.531804               1.378479
# Algeria                9076.854672               1.317920
# Angola                 9288.487977               1.224589
# ...                            ...                    ...
# Venezuela              6689.882755               1.293403
# Vietnam                5692.683008               1.190175
# Yemen                  5822.812738               1.375644
# Zambia                 7467.311343               1.467202
# Zimbabwe               5104.663309               1.523511
#
#              E_destock_normalized  P_pv_normalized  P_wind_normalized  \
# Country
# France                6957.900123         2.712910           2.396084
# Afghanistan           6981.414414         0.000919           3.874363
# Albania              17657.459412         0.003247           2.004428
# Algeria               7916.065294         0.001109           2.946682
# Angola               15953.820542         0.002793           4.648630
# ...                           ...              ...                ...
# Venezuela            14830.309690         4.730406           0.852252
# Vietnam              13075.194418         4.782216           1.846433
# Yemen                 8229.760087         2.079573           2.285321
# Zambia               13994.692360         4.332429           0.796654
# Zimbabwe             14644.753511         3.940032           1.303944
#
#              capacity_factor_wind  capacity_factor_pv  \
# Country
# France                   1.336909            0.662260
# Afghanistan              1.075657          905.686513
# Albania                  1.027741          905.523997
# Algeria                  0.365768         3537.314104
# Angola                   0.531501          905.688161
# ...                           ...                 ...
# Venezuela                0.743307            0.923074
# Vietnam                  0.801109            0.736229
# Yemen                    1.207785            1.077059
# Zambia                   0.630806            1.038093
# Zimbabwe                 0.715252            1.032315
#
#              capacity_factor_dispatch  share_dispatchable  share_wind  \
# Country
# France                       0.480940           12.588869   56.001641
# Afghanistan                  0.566461           11.383468   73.861633
# Albania                      0.830653           18.633537   33.523501
# Algeria                      0.502074           11.687196   19.036753
# Angola                       0.865865           17.496238   40.769249
# ...                               ...                 ...         ...
# Venezuela                    0.590446           13.249947   10.990982
# Vietnam                      0.546012           11.502070   26.181105
# Yemen                        0.483195           11.734145   48.725869
# Zambia                       0.580992           14.565444    8.586759
# Zimbabwe                     0.382488           10.437989   16.705963
#
#               share_pv
# Country
# France       31.409490
# Afghanistan  14.754899
# Albania      47.842962
# Algeria      69.276051
# Angola       41.734513
# ...                ...
# Venezuela    75.759071
# Vietnam      62.316825
# Yemen        39.539986
# Zambia       76.847797
# Zimbabwe     72.856049
#
# [160 rows x 20 columns]

# %%
data[data['iso_alpha']=='ARG']
# Out:
#            State iso_alpha     mean_load    E_dispatch    P_dispatch  \
# Country
# Argentina    NaN       ARG  17627.853425  7.904558e+07  20908.364161
#
#               E_destock      P_pv        P_wind  mean_load_normalized  \
# Country
# Argentina  7.483008e+07  3.307519  66871.991818                   1.0
#
#            E_dispatch_normalized  P_dispatch_normalized  E_destock_normalized  \
# Country
# Argentina            4484.129552               1.186098            4244.99092
#
#            P_pv_normalized  P_wind_normalized  capacity_factor_wind  \
# Country
# Argentina         0.000188           3.793541              1.273234
#
#            capacity_factor_pv  capacity_factor_dispatch  share_dispatchable  \
# Country
# Argentina          905.677568                  0.431572            9.286964
#
#            share_wind  share_pv
# Country
# Argentina   87.630017   3.08302

# %%
data_us = pd.read_csv('results/optimization_results_CHU_world_grid_with_states.csv')
data_us = data_us.set_index('State')

for col in data_us.columns[2:]: 
    data_us[f'{col}_normalized']=data_us[col]/data_us['mean_load']

for i in range(len(data_us.index.to_list())): 
    c = data_us.index[i]
    country_name = data_us.iloc[i,0]
    results = pd.read_pickle(f'./results/{country_name}/Chu/optimization_results_{c}.pickle')
    iso_code = country_codes.loc[country_name,'Alpha-3 code' ].split(' ')[1]
    # pop = pop_data.loc[iso_code]
    # pop=pop.iloc[0]
    data_us.loc[c, 'capacity_factor_wind'] = results['E_wind']/data_us.loc[c, 'P_wind']/8760
    data_us.loc[c, 'capacity_factor_pv'] = results['E_pv']/data_us.loc[c, 'P_pv']/8760
    data_us.loc[c, 'capacity_factor_dispatch'] = results['E_dispatch']/data_us.loc[c, 'P_dispatch']/8760
    data_us.loc[c, 'share_dispatchable'] = results['E_dispatch']/(results['E_wind']+results['E_pv']+results['E_dispatch'])*100
    data_us.loc[c, 'share_wind']=results['E_wind']/(results['E_wind']+results['E_pv']+results['E_dispatch'])*100
    data_us.loc[c, 'share_pv']=results['E_pv']/(results['E_wind']+results['E_pv']+results['E_dispatch'])*100
    # data_us.loc[c, 'carbon_impact']=results['E_wind']*11+results['E_pv']*45/pop/1000

# %%
data_us
# Out:
#          Country iso_alpha     mean_load    E_dispatch    P_dispatch  \
# State
# ALT       Russia       RUS  24440.439612  1.441800e+08  28127.253628
# ALT       Russia       RUS  24440.439612  1.441800e+08  28127.253628
# MO        Russia       RUS  27475.774886  1.918995e+08  34279.256979
# TUL       Russia       RUS  27475.774886  1.918995e+08  34279.256979
# KGN       Russia       RUS  30910.773402  1.711221e+08  32888.989517
# ...          ...       ...           ...           ...           ...
# Region4   Brazil       BRA  11167.780365  7.192756e+07  13008.668411
# Region5   Brazil       BRA  11167.780365  5.808778e+07  12672.912161
# Region6   Brazil       BRA  11167.780365  5.912110e+07  12609.997109
# Region9   Brazil       BRA  34724.832763  1.973536e+08  43531.574515
# Regoin14  Brazil       BRA  11870.570434  6.030664e+07  14630.217898
#
#              E_destock           P_pv        P_wind  mean_load_normalized  \
# State
# ALT       1.658357e+08   59749.683468  68599.052179                   1.0
# ALT       1.658357e+08   59749.683468  68599.052179                   1.0
# MO        2.161079e+08   83325.056984  80640.608776                   1.0
# TUL       2.161079e+08   83325.056984  80640.608776                   1.0
# KGN       1.962977e+08   72008.735045  84172.484262                   1.0
# ...                ...            ...           ...                   ...
# Region4   1.692779e+08   50041.763751  11055.590962                   1.0
# Region5   1.653741e+08   47429.581717  16145.539979                   1.0
# Region6   1.664105e+08   49447.490500  13248.739608                   1.0
# Region9   4.537171e+08  148332.530272  59450.882287                   1.0
# Regoin14  1.015352e+08   37227.495836  26833.757633                   1.0
#
#           E_dispatch_normalized  P_dispatch_normalized  E_destock_normalized  \
# State
# ALT                 5899.241073               1.150849           6785.298550
# ALT                 5899.241073               1.150849           6785.298550
# MO                  6984.314660               1.247617           7865.397092
# TUL                 6984.314660               1.247617           7865.397092
# KGN                 5536.000393               1.063998           6350.461561
# ...                         ...                    ...                   ...
# Region4             6440.631425               1.164839          15157.704878
# Region5             5201.372019               1.134774          14808.143160
# Region6             5293.899243               1.129141          14900.950944
# Region9             5683.356974               1.253615          13066.071436
# Regoin14            5080.348783               1.232478           8553.523715
#
#           P_pv_normalized  P_wind_normalized  capacity_factor_wind  \
# State
# ALT              2.444706           2.806785              1.198777
# ALT              2.444706           2.806785              1.198777
# MO               3.032674           2.934971              0.294121
# TUL              3.032674           2.934971              1.121471
# KGN              2.329568           2.723079              1.309351
# ...                   ...                ...                   ...
# Region4          4.480905           0.989954              0.672374
# Region5          4.247002           1.445725              0.694222
# Region6          4.427692           1.186336              0.731873
# Region9          4.271656           1.712057              0.623539
# Regoin14         3.136117           2.260528              0.987200
#
#           capacity_factor_pv  capacity_factor_dispatch  share_dispatchable  \
# State
# ALT                 0.668911                  0.585159           11.869882
# ALT                 0.668911                  0.585159           11.869882
# MO                  0.523555                  0.284608           12.653994
# TUL                 0.563369                  0.639055           13.752897
# KGN                 0.615794                  0.593952           11.221016
# ...                      ...                       ...                 ...
# Region4             0.967300                  0.631187           12.819567
# Region5             0.940981                  0.523244           10.614748
# Region6             0.933162                  0.535209           10.783212
# Region9             0.920595                  0.517531           11.485391
# Regoin14            0.882750                  0.470555           10.393438
#
#           share_wind   share_pv
# State
# ALT        59.306429  28.823689
# ALT        59.306429  28.823689
# MO         30.762945  56.583061
# TUL        56.776223  29.470879
# KGN        63.307715  25.471269
# ...              ...        ...
# Region4    11.605803  75.574630
# Region5    17.942367  71.442885
# Region6    15.492448  73.724340
# Region9    18.898480  69.616130
# Regoin14   39.993074  49.613488
#
# [188 rows x 20 columns]

# %%
# shapefile_path = './shapefiles/geoBoundariesCGAZ_ADM1.shp'
# gdf = gpd.read_file(shapefile_path)

# gdf = gdf.to_crs(epsg=4326)

# gdf['geometry'] = gdf['geometry'].simplify(tolerance=0.01)

# fig, ax = plt.subplots(figsize=(10, 10))
# gdf.plot(ax=ax, linewidth=0.5, edgecolor='k', color='lightblue')

# ax.set_title('Your Title Here')

# ax.set_axis_off()

# plt.show()

# %%
fig = go.Figure(go.Choropleth(
    locations=data['iso_alpha'],
    z=data['share_dispatchable'],
    text=data['iso_alpha'],
    hoverinfo='location+z+text',
    colorscale='Portland', zmin=0,  
    zmax=25 
))

fig.update_layout(
    title_text='Dispatchable energy (% of production)',
    geo=dict(
        projection=go.layout.geo.Projection(type='natural earth')
    )
)
# Save the figure as an HTML file without displaying it
fig.write_html('figures/world_maps/choropleth_map_chu_dispatch.html')

# %%
fig = go.Figure(go.Choropleth(
    locations=data['iso_alpha'],
    z=data['share_pv'],
    text=data['iso_alpha'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100 
))

fig.update_layout(
    title_text='PV energy (% of production)',
    geo=dict(
        projection=go.layout.geo.Projection(type='natural earth')
    )
)
# Save the figure as an HTML file without displaying it
fig.write_html('figures/world_maps/choropleth_map_chu_pv_share.html')

# %%
fig = go.Figure(go.Choropleth(
    locations=data['iso_alpha'],
    z=data['share_wind'],
    text=data['iso_alpha'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100 
))

fig.update_layout(
    title_text='Wind energy (% of production)',
    geo=dict(
        projection=go.layout.geo.Projection(type='natural earth')
    )
)
# Save the figure as an HTML file without displaying it
fig.write_html('figures/world_maps/choropleth_map_chu_wind_share.html')

# %% [markdown]
# ### Chargement des shapefiles

# %%
world = gpd.read_file('shapefiles/ne_110m_admin_0_countries.shp')

usa_gdf = gpd.read_file('shapefiles/USA/States_shapefile.shp')
usa_gdf = usa_gdf.merge(data_us[data_us['iso_alpha']=='USA'], left_on='State_Code', right_on='State')  

canada_gdf = gpd.read_file('shapefiles/Canada/Canada_Provincial_boundaries_generalized.shp')
canada_gdf = canada_gdf.to_crs(world.crs)
canada_gdf = canada_gdf.merge(data_us[data_us['iso_alpha']=='CAN'], left_on='postal', right_on='State')  

china_gdf = gpd.read_file('shapefiles/China/chn_admbnda_adm1_ocha_2020.shp')
china_gdf = china_gdf.merge(data_us[data_us['iso_alpha']=='CHN'], left_on='ADM1_PCODE', right_on='State')
# brazil_gdf = gpd.read_file('shapefiles/Brazil/geoBoundaries-BRA-ADM1.shp')
# for i in brazil_gdf.index :
#     brazil_gdf.loc[i,'shapeISO'] = brazil_gdf.loc[i,'shapeISO'].split('-')[1]
# brazil_gdf = brazil_gdf.merge(data_us, left_on='shapeISO', right_on='State')

# india_gdf = gpd.read_file('shapefiles/China/chn_admbnda_adm1_ocha_2020.shp')
# india_gdf = india_gdf.merge(data_us, left_on='State_Code', right_on='State')
australia_gdf = gpd.read_file('shapefiles/Australia/georef-australia-state-millesime.shp')
australia_gdf = australia_gdf.merge(data_us[data_us['iso_alpha']=='AUS'], left_on='ste_iso3166', right_on='State')

russia_gdf = gpd.read_file('shapefiles/Russia/geoBoundaries-RUS-ADM1.shp')
russia_gdf["geometry"]=(russia_gdf.to_crs(russia_gdf.estimate_utm_crs()).simplify(1000).to_crs(russia_gdf.crs))
for i in russia_gdf.index :
    russia_gdf.loc[i,'shapeISO'] = russia_gdf.loc[i,'shapeISO'].split('-')[1]
russia_gdf = russia_gdf.to_crs(world.crs)
russia_gdf = russia_gdf.merge(data_us[data_us['iso_alpha']=='RUS'], left_on='shapeISO', right_on='State')

# %%
shapefile_path = '../../../DATA/Chu et Hawkes/Shapefiles/Zone/Zone_Boundry.shp'
chu_gdf = gpd.read_file(shapefile_path)

chu_gdf = chu_gdf.to_crs(epsg=4326)

chu_gdf['geometry'] = chu_gdf['geometry'].simplify(tolerance=0.01)

# %%
usa_gdf
# Out:
#     FID          Program State_Code      State_Name Flowing_St  FID_1  \
# 0     1  PERMIT TRACKING         AL         ALABAMA          F    919
# 1     2             None         AK          ALASKA          N    920
# 2     3          AZURITE         AZ         ARIZONA          F    921
# 3     4              PDS         AR        ARKANSAS          F    922
# 4     5             None         CA      CALIFORNIA          N    923
# 5     6           ECOMAP         CO        COLORADO          F    924
# 6     7             SIMS         CT     CONNECTICUT          F    925
# 7     8             None         DE        DELAWARE          P    926
# 8    10             None         FL         FLORIDA          P    928
# 9    11             None         GA         GEORGIA          N    929
# 10   12           HI-EHW         HI          HAWAII          F    930
# 11   13             None         ID           IDAHO          P    931
# 12   14             ACES         IL        ILLINOIS          F    932
# 13   15           IN-FRS         IN         INDIANA          F    933
# 14   16         IDNR_EFD         IA            IOWA          F    934
# 15   17            KS-FP         KS          KANSAS          F    935
# 16   18         KY-TEMPO         KY        KENTUCKY          F    936
# 17   19             None         LA       LOUISIANA          P    937
# 18   20          ME-EFIS         ME           MAINE          F    938
# 19   21             None         MD        MARYLAND          P    939
# 20   22         MA-EPICS         MA   MASSACHUSETTS          F    940
# 21   23             None         MI        MICHIGAN          P    941
# 22   24         MN-DELTA         MN       MINNESOTA          F    942
# 23   25        MS-ENSITE         MS     MISSISSIPPI          F    943
# 24   26           MO-DNR         MO        MISSOURI          F    944
# 25   27        MT-CEDARS         MT         MONTANA          F    945
# 26   28             NDEQ         NE        NEBRASKA          F    946
# 27   29            NV-FP         NV          NEVADA          F    947
# 28   30           NH-DES         NH   NEW HAMPSHIRE          F    948
# 29   31         NJ-NJEMS         NJ      NEW JERSEY          F    949
# 30   32             None         NM      NEW MEXICO          P    950
# 31   33              FIS         NY        NEW YORK          F    951
# 32   34             None         NC  NORTH CAROLINA          N    952
# 33   35             None         ND    NORTH DAKOTA          N    953
# 34   36             None         OH            OHIO          P    954
# 35   37           OK-FMS         OK        OKLAHOMA          F    955
# 36   38             None         OR          OREGON          N    956
# 37   39        PA-EFACTS         PA    PENNSYLVANIA          F    957
# 38   40             None         RI    RHODE ISLAND          N    958
# 39   41             None         SC  SOUTH CAROLINA          N    959
# 40   42             None         SD    SOUTH DAKOTA          P    960
# 41   43             None         TN       TENNESSEE          P    961
# 42   44      TX-TCEQ ACR         TX           TEXAS          F    962
# 43   45             None         UT            UTAH          N    963
# 44   46             None         VT         VERMONT          P    964
# 45   47             None         VA        VIRGINIA          P    965
# 46   48          WA-FSIS         WA      WASHINGTON          F    966
# 47   49             None         WV   WEST VIRGINIA          N    967
# 48   50           WI-ESR         WI       WISCONSIN          F    968
# 49   51             None         WY         WYOMING          N    969
#
#                                              geometry        Country  \
# 0   POLYGON ((-85.07007 31.98070, -85.11515 31.907...  United States
# 1   MULTIPOLYGON (((-161.33379 58.73325, -161.3824...  United States
# 2   POLYGON ((-114.52063 33.02771, -114.55909 33.0...  United States
# 3   POLYGON ((-94.46169 34.19677, -94.45262 34.508...  United States
# 4   MULTIPOLYGON (((-121.66522 38.16929, -121.7823...  United States
# 5   POLYGON ((-102.04446 37.64147, -102.04201 37.3...  United States
# 6   POLYGON ((-73.53039 41.52275, -73.51715 41.665...  United States
# 7   POLYGON ((-75.70707 38.55759, -75.71071 38.649...  United States
# 8   MULTIPOLYGON (((-80.78566 28.78519, -80.76242 ...  United States
# 9   MULTIPOLYGON (((-85.13016 31.77885, -85.13156 ...  United States
# 10  MULTIPOLYGON (((-160.07380 22.00418, -160.0497...  United States
# 11  POLYGON ((-117.02630 43.67903, -117.02379 43.7...  United States
# 12  POLYGON ((-88.07159 37.51104, -88.08791 37.476...  United States
# 13  POLYGON ((-86.34161 38.17729, -86.36435 38.193...  United States
# 14  POLYGON ((-91.12013 40.70544, -91.12930 40.682...  United States
# 15  POLYGON ((-95.07193 37.00148, -95.40662 37.000...  United States
# 16  MULTIPOLYGON (((-86.51067 36.65507, -86.77054 ...  United States
# 17  MULTIPOLYGON (((-93.70752 30.23958, -93.69938 ...  United States
# 18  MULTIPOLYGON (((-69.77728 44.07415, -69.85993 ...  United States
# 19  MULTIPOLYGON (((-75.71071 38.64967, -75.70707 ...  United States
# 20  MULTIPOLYGON (((-71.31933 41.77220, -71.33980 ...  United States
# 21  MULTIPOLYGON (((-88.49753 48.17380, -88.62533 ...  United States
# 22  POLYGON ((-91.73037 43.49957, -92.07753 43.499...  United States
# 23  POLYGON ((-88.45080 31.43562, -88.43456 31.120...  United States
# 24  POLYGON ((-89.10503 36.95392, -89.12965 36.866...  United States
# 25  POLYGON ((-111.47543 44.70216, -111.48080 44.6...  United States
# 26  POLYGON ((-101.40739 40.00100, -102.05154 39.9...  United States
# 27  POLYGON ((-119.15245 38.41180, -119.31883 38.5...  United States
# 28  POLYGON ((-72.27992 42.72047, -72.45577 42.725...  United States
# 29  POLYGON ((-75.48928 39.71486, -75.47597 39.720...  United States
# 30  POLYGON ((-109.04950 32.44204, -109.05135 32.7...  United States
# 31  MULTIPOLYGON (((-79.76323 42.26733, -79.44402 ...  United States
# 32  MULTIPOLYGON (((-83.98845 34.98915, -84.11815 ...  United States
# 33  POLYGON ((-98.73044 45.93827, -99.00683 45.939...  United States
# 34  POLYGON ((-83.27275 38.60926, -83.29004 38.596...  United States
# 35  POLYGON ((-94.43932 34.92915, -94.44596 34.735...  United States
# 36  POLYGON ((-121.44151 41.99433, -122.28471 42.0...  United States
# 37  POLYGON ((-77.47579 39.71962, -78.09595 39.725...  United States
# 38  MULTIPOLYGON (((-71.79019 41.60131, -71.79261 ...  United States
# 39  MULTIPOLYGON (((-81.75959 33.19538, -81.76988 ...  United States
# 40  POLYGON ((-102.78838 42.99530, -103.00588 42.9...  United States
# 41  POLYGON ((-83.95461 35.45554, -84.01256 35.407...  United States
# 42  MULTIPOLYGON (((-105.99889 31.39394, -106.2132...  United States
# 43  POLYGON ((-114.04727 38.13765, -114.04509 38.5...  United States
# 44  POLYGON ((-73.25806 42.74606, -73.26928 42.747...  United States
# 45  MULTIPOLYGON (((-79.14406 36.54620, -79.21680 ...  United States
# 46  MULTIPOLYGON (((-122.40202 48.22522, -122.4628...  United States
# 47  POLYGON ((-79.23166 38.48050, -79.27236 38.437...  United States
# 48  MULTIPOLYGON (((-87.74855 44.96162, -87.83999 ...  United States
# 49  POLYGON ((-104.05362 41.69822, -104.05550 41.5...  United States
#
#    iso_alpha     mean_load  ...  P_dispatch_normalized  E_destock_normalized  \
# 0        USA  30181.690868  ...               1.580276          13012.435948
# 1        USA    698.117808  ...               1.152627           6771.274526
# 2        USA  16703.710046  ...               1.654430          14212.116210
# 3        USA  18807.470205  ...               1.484611          12343.595824
# 4        USA  34194.854452  ...               1.548654          12834.205662
# 5        USA   8189.022945  ...               1.293750          11019.886885
# 6        USA  15899.369178  ...               1.608123          11397.818130
# 7        USA  34429.318037  ...               1.504856          11562.137445
# 8        USA  28593.382763  ...               1.420778          12625.511470
# 9        USA  30181.690868  ...               1.614325          12940.468231
# 10       USA   1078.085388  ...               1.360355          14634.277674
# 11       USA  30287.193493  ...               1.308389          11641.144686
# 12       USA  66313.661872  ...               1.366612          10302.634680
# 13       USA  66313.661872  ...               1.409767          10265.360375
# 14       USA  24881.513128  ...               1.309764           9675.528893
# 15       USA   8374.291096  ...               1.550868          10249.265589
# 16       USA  27498.863242  ...               1.708278          11361.317975
# 17       USA  18807.470205  ...               1.486942          12767.935997
# 18       USA  15899.369178  ...               1.563016          10168.432211
# 19       USA  34429.318037  ...               1.510702          11221.114784
# 20       USA  15899.369178  ...               1.540833          10709.756109
# 21       USA  12257.104338  ...               1.439403           9557.149553
# 22       USA  24881.513128  ...               1.291730           9187.132946
# 23       USA  30181.690868  ...               1.636643          12849.524284
# 24       USA  13468.655936  ...               1.367565          10486.961547
# 25       USA  24881.513128  ...               1.154188           9353.435090
# 26       USA  24881.513128  ...               1.234838           8818.189117
# 27       USA  30287.193493  ...               1.331794          13740.431994
# 28       USA  15899.369178  ...               1.593778          10314.816613
# 29       USA  34429.318037  ...               1.531545          11601.456740
# 30       USA  16703.710046  ...               1.680186          13918.990937
# 31       USA  19832.226256  ...               1.456864          10481.533189
# 32       USA  39726.935845  ...               1.648397          11646.955943
# 33       USA  24881.513128  ...               1.244053           8416.573496
# 34       USA  66313.661872  ...               1.365645          10288.029439
# 35       USA  18593.838584  ...               1.591736          12213.044606
# 36       USA  30287.193493  ...               1.268958          11444.440438
# 37       USA  34429.318037  ...               1.505569          10855.987791
# 38       USA  15899.369178  ...               1.612428          11481.220516
# 39       USA  39726.935845  ...               1.719102          11873.785767
# 40       USA  24881.513128  ...               1.245423           8794.272307
# 41       USA  27498.863242  ...               1.662245          11612.001825
# 42       USA  45252.203082  ...               1.450436          12122.926998
# 43       USA   8189.022945  ...               1.304887          13641.896622
# 44       USA  15899.369178  ...               1.544191          10065.475314
# 45       USA  39726.935845  ...               1.672226          11824.539381
# 46       USA  30287.193493  ...               1.415817           9259.933182
# 47       USA  66313.661872  ...               1.368949          11415.943955
# 48       USA   2892.080137  ...               1.311258           9871.002994
# 49       USA  24881.513128  ...               1.253313          10721.584319
#
#     P_pv_normalized  P_wind_normalized  capacity_factor_wind  \
# 0          4.165167           2.371595              0.572510
# 1          3.495502           2.310657              1.374998
# 2          3.952525           1.015720              0.721346
# 3          4.486179           1.208854              0.967542
# 4          3.527362           1.762235              0.762964
# 5          3.317788           1.520205              1.141493
# 6          4.392881           1.715717              0.951418
# 7          4.387778           1.322270              1.106036
# 8          4.452522           1.475394              0.566344
# 9          4.202006           2.184727              0.589488
# 10         4.393166           0.657289              1.290247
# 11         3.651534           2.055774              0.852152
# 12         3.921184           1.322201              1.396837
# 13         3.984349           1.403268              1.352746
# 14         3.631471           1.293961              1.623943
# 15         3.620547           1.012527              1.746913
# 16         4.367732           1.679804              0.924638
# 17         4.423889           1.626448              0.654966
# 18         4.291073           1.822458              1.052731
# 19         4.415711           1.423704              1.066292
# 20         4.193332           1.690012              1.080073
# 21         3.960379           1.703982              1.267007
# 22         3.580613           1.582705              1.441531
# 23         4.187939           1.769540              0.739844
# 24         3.909096           1.393084              1.264088
# 25         3.369974           1.602321              1.402580
# 26         3.032127           1.294760              1.809616
# 27         3.811682           1.409800              0.823081
# 28         4.313941           1.753453              1.060171
# 29         4.462598           1.629341              0.936573
# 30         3.872402           0.728468              1.142946
# 31         4.501016           1.719042              1.074437
# 32         4.336617           1.667774              0.780384
# 33         3.145396           1.480305              1.708613
# 34         4.178791           1.718226              1.120237
# 35         4.029545           0.792601              1.671719
# 36         3.802968           2.220047              0.786821
# 37         4.499799           1.778093              0.976147
# 38         4.279618           1.563147              1.068436
# 39         4.331483           1.960061              0.619780
# 40         3.124667           1.388838              1.736842
# 41         4.352896           1.659114              0.850647
# 42         3.904489           0.942815              1.303436
# 43         3.897769           1.446668              0.788165
# 44         4.321812           1.973127              1.013556
# 45         4.461681           1.793371              0.753276
# 46         3.553059           2.701931              0.830761
# 47         4.524500           1.853442              0.859679
# 48         3.843462           1.661096              1.264552
# 49         3.340632           1.408220              1.378689
#
#     capacity_factor_pv  capacity_factor_dispatch  share_dispatchable  \
# 0             0.874452                  0.560623           15.051791
# 1             0.521485                  0.481455            9.989991
# 2             1.079643                  0.477466           13.643224
# 3             0.853818                  0.514275           13.247125
# 4             1.036321                  0.408478           11.230901
# 5             0.983998                  0.495369           11.361398
# 6             0.766612                  0.484319           13.477520
# 7             0.806222                  0.517930           13.485973
# 8             0.935295                  0.560907           13.747371
# 9             0.883419                  0.568883           15.517171
# 10            0.945089                  0.446822           10.839064
# 11            0.889535                  0.496958           11.507785
# 12            0.804120                  0.512530           12.287317
# 13            0.778480                  0.505627           12.477481
# 14            0.798211                  0.543626           12.465324
# 15            0.892463                  0.440536           12.021605
# 16            0.789149                  0.469291           13.818052
# 17            0.889428                  0.543095           13.905186
# 18            0.718105                  0.496030           13.424454
# 19            0.788529                  0.509449           13.339252
# 20            0.757074                  0.492130           13.168668
# 21            0.717366                  0.479912           12.138691
# 22            0.759222                  0.565258           12.742407
# 23            0.881296                  0.548168           15.213347
# 24            0.828585                  0.529671           12.653994
# 25            0.816807                  0.536919           11.027364
# 26            0.876276                  0.508802           11.163044
# 27            1.007330                  0.532897           12.429856
# 28            0.728114                  0.509147           13.963195
# 29            0.778471                  0.519619           13.730917
# 30            1.076180                  0.457649           13.328907
# 31            0.700508                  0.493723           12.576511
# 32            0.852853                  0.497789           14.097515
# 33            0.785507                  0.577385           12.561389
# 34            0.735902                  0.531703           12.680812
# 35            0.912012                  0.447374           12.466537
# 36            0.855442                  0.510051           11.461063
# 37            0.725437                  0.505110           13.201646
# 38            0.778078                  0.470405           13.171750
# 39            0.873879                  0.489356           14.401933
# 40            0.828187                  0.530993           11.681233
# 41            0.824435                  0.476396           13.672355
# 42            0.965837                  0.483946           12.310425
# 43            0.990255                  0.565546           12.861216
# 44            0.694182                  0.512382           13.662342
# 45            0.817875                  0.483075           13.909039
# 46            0.775484                  0.504654           12.503248
# 47            0.752931                  0.539860           12.877428
# 48            0.754387                  0.547875           12.563026
# 49            0.915546                  0.475648           10.652634
#
#     share_wind   share_pv
# 0    23.067904  61.880305
# 1    57.195030  32.814979
# 2    12.654472  73.702304
# 3    20.293539  66.459335
# 4    23.870411  64.898688
# 5    30.762980  57.875622
# 6    28.247230  58.275250
# 7    25.304978  61.209049
# 8    14.414189  71.838440
# 9    21.760576  62.722253
# 10   15.122851  74.038085
# 11   31.004695  57.487521
# 12   32.399302  55.313381
# 13   33.228191  54.294328
# 14   36.787654  50.747023
# 15   31.123163  56.855232
# 16   26.771749  59.410199
# 17   18.342818  67.751995
# 18   33.220032  53.355513
# 19   26.311656  60.349092
# 20   31.699281  55.132051
# 21   37.937756  49.923553
# 22   39.815971  47.441622
# 23   22.200264  62.586390
# 24   30.762945  56.583061
# 25   39.991123  48.981513
# 26   41.629327  47.207628
# 27   20.322911  67.247233
# 28   31.987794  54.049011
# 29   26.329259  59.939824
# 30   14.432464  72.238628
# 31   32.294273  55.129215
# 32   22.360490  63.541996
# 33   44.231154  43.207457
# 34   33.614755  53.704433
# 35   23.196477  64.336986
# 36   30.931608  57.607329
# 37   30.130844  56.667511
# 38   29.002763  57.825486
# 39   20.797025  64.801042
# 40   42.608362  45.710405
# 41   24.367184  61.960461
# 42   21.552319  66.137256
# 43   19.871358  67.267426
# 44   34.532892  51.804767
# 45   23.260108  62.830853
# 46   39.280084  48.216667
# 47   27.763618  59.358954
# 48   36.733010  50.703964
# 49   34.693536  54.653830
#
# [50 rows x 27 columns]

# %% [markdown]
# ## Couche Brésil

# %%
data_bra = data_us[data_us['iso_alpha']=='BRA']
data_bra = data_bra.reset_index()
for i in range(len(data_bra)):
    data_bra.loc[i, 'State']='BRA.'+data_bra.loc[i, 'State']

# %%
brazil_gdf = chu_gdf.merge(data_bra, left_on='Zone_L2', right_on='State')

# %% [markdown]
# ### Carte énergie pilotable

# %%
fig = go.Figure(go.Choropleth(
    locations=data['iso_alpha'],
    z=data['share_dispatchable'],
    text=data['iso_alpha'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20 
))

# Adding Canada provinces
fig.add_trace(go.Choropleth(
    geojson=canada_gdf.geometry.__geo_interface__,
    locations=canada_gdf.index,
    z=canada_gdf['share_dispatchable'],
    text=canada_gdf['Name_EN'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20
))

# Adding Brazil states
fig.add_trace(go.Choropleth(
    geojson=brazil_gdf.geometry.__geo_interface__,
    locations=brazil_gdf.index,
    z=brazil_gdf['share_dispatchable'],
    text=brazil_gdf['State'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20
))

# Adding Russia regions
fig.add_trace(go.Choropleth(
    geojson=russia_gdf.geometry.__geo_interface__,
    locations=russia_gdf.index,
    z=russia_gdf['share_dispatchable'],
    text=russia_gdf['shapeISO'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20
))

# Adding Australia states
fig.add_trace(go.Choropleth(
    geojson=australia_gdf.geometry.__geo_interface__,
    locations=australia_gdf.index,
    z=australia_gdf['share_dispatchable'],
    text=australia_gdf['ste_code'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20
))

# Adding China provinces
fig.add_trace(go.Choropleth(
    geojson=china_gdf.geometry.__geo_interface__,
    locations=china_gdf.index,
    z=china_gdf['share_dispatchable'],
    text=china_gdf['ADM1_PCODE'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20
))

# Adding USA states
fig.add_trace(go.Choropleth(
    geojson=usa_gdf.geometry.__geo_interface__,
    locations=usa_gdf.index,
    z=usa_gdf['share_dispatchable'],
    text=usa_gdf['State_Name'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=20
))

# Update layout and map projection
fig.update_layout(
    title_text='Dispatchable Energy (% of production)',
    geo=dict(
        projection=go.layout.geo.Projection(type='natural earth')
    )
)

# Save the figure as an HTML file
fig.write_html('figures/world_maps/choropleth_map_dispatch_chu_with_states.html')

# %% [markdown]
# ### Carte énerie PV

# %%
fig = go.Figure(go.Choropleth(
    locations=data['iso_alpha'],
    z=data['share_pv'],
    text=data['iso_alpha'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Canada provinces
fig.add_trace(go.Choropleth(
    geojson=canada_gdf.geometry.__geo_interface__,
    locations=canada_gdf.index,
    z=canada_gdf['share_pv'],
    text=canada_gdf['Name_EN'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Brazil states
fig.add_trace(go.Choropleth(
    geojson=brazil_gdf.geometry.__geo_interface__,
    locations=brazil_gdf.index,
    z=brazil_gdf['share_pv'],
    text=brazil_gdf['State'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Russia regions
fig.add_trace(go.Choropleth(
    geojson=russia_gdf.geometry.__geo_interface__,
    locations=russia_gdf.index,
    z=russia_gdf['share_pv'],
    text=russia_gdf['shapeISO'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Australia states
fig.add_trace(go.Choropleth(
    geojson=australia_gdf.geometry.__geo_interface__,
    locations=australia_gdf.index,
    z=australia_gdf['share_pv'],
    text=australia_gdf['ste_code'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding China provinces
fig.add_trace(go.Choropleth(
    geojson=china_gdf.geometry.__geo_interface__,
    locations=china_gdf.index,
    z=china_gdf['share_pv'],
    text=china_gdf['ADM1_PCODE'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding USA states
fig.add_trace(go.Choropleth(
    geojson=usa_gdf.geometry.__geo_interface__,
    locations=usa_gdf.index,
    z=usa_gdf['share_pv'],
    text=usa_gdf['State_Name'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Update layout and map projection
fig.update_layout(
    title_text='PV Energy (% of production)',
    geo=dict(
        projection=go.layout.geo.Projection(type='natural earth')
    )
)


# Save the figure as an HTML file
fig.write_html('figures/world_maps/choropleth_map_pv_chu_with_states.html')

# %% [markdown]
# ### Carte énergie éolienne

# %%
fig = go.Figure(go.Choropleth(
    locations=data['iso_alpha'],
    z=data['share_wind'],
    text=data['iso_alpha'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Canada provinces
fig.add_trace(go.Choropleth(
    geojson=canada_gdf.geometry.__geo_interface__,
    locations=canada_gdf.index,
    z=canada_gdf['share_wind'],
    text=canada_gdf['Name_EN'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Brazil states
fig.add_trace(go.Choropleth(
    geojson=brazil_gdf.geometry.__geo_interface__,
    locations=brazil_gdf.index,
    z=brazil_gdf['share_wind'],
    text=brazil_gdf['State'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Russia regions
fig.add_trace(go.Choropleth(
    geojson=russia_gdf.geometry.__geo_interface__,
    locations=russia_gdf.index,
    z=russia_gdf['share_wind'],
    text=russia_gdf['shapeISO'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding Australia states
fig.add_trace(go.Choropleth(
    geojson=australia_gdf.geometry.__geo_interface__,
    locations=australia_gdf.index,
    z=australia_gdf['share_wind'],
    text=australia_gdf['ste_code'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding China provinces
fig.add_trace(go.Choropleth(
    geojson=china_gdf.geometry.__geo_interface__,
    locations=china_gdf.index,
    z=china_gdf['share_wind'],
    text=china_gdf['ADM1_PCODE'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Adding USA states
fig.add_trace(go.Choropleth(
    geojson=usa_gdf.geometry.__geo_interface__,
    locations=usa_gdf.index,
    z=usa_gdf['share_wind'],
    text=usa_gdf['State_Name'],
    hoverinfo='location+z+text',
    colorscale='Portland', 
    zmin=0,  
    zmax=100
))

# Update layout and map projection
fig.update_layout(
    title_text='Wind Energy (% of production)',
    geo=dict(
        projection=go.layout.geo.Projection(type='natural earth')
    )
)

# Save the figure as an HTML file
fig.write_html('figures/world_maps/choropleth_map_wind_chu_with_states.html')
